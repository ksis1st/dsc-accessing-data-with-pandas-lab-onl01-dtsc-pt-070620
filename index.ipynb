# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a dataset which contains information on World Cup matches. Let's use the Pandas commands learned in the previous lesson to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# - Use pandas methods and attributes to access information about a dataset
# - Index pandas dataframes with .loc, .iloc, and column names
# - Use a boolean mask to index pandas series and dataframes

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `'WorldCupMatches.csv'` as a DataFrame in Pandas.

# %%
# Import pandas using the standard alias

import pandas as pd 
# Import 'WorldCupMatches.csv' as a DataFrame
df = pd.read_csv('WorldCupMatches.csv')
df.head()
# Out:
#    Year              Datetime  ... Home Team Initials Away Team Initials
# 0  1930  13 Jul 1930 - 15:00   ...                FRA                MEX
# 1  1930  13 Jul 1930 - 15:00   ...                USA                BEL
# 2  1930  14 Jul 1930 - 12:45   ...                YUG                BRA
# 3  1930  14 Jul 1930 - 14:50   ...                ROU                PER
# 4  1930  15 Jul 1930 - 16:00   ...                ARG                FRA
#
# [5 rows x 20 columns]

# %%
df.shape
# Out:
# (852, 20)

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the dataset.

# %%
# Print the first 7 rows of df
df.head(7)
# Out:
#    Year              Datetime  ... Home Team Initials Away Team Initials
# 0  1930  13 Jul 1930 - 15:00   ...                FRA                MEX
# 1  1930  13 Jul 1930 - 15:00   ...                USA                BEL
# 2  1930  14 Jul 1930 - 12:45   ...                YUG                BRA
# 3  1930  14 Jul 1930 - 14:50   ...                ROU                PER
# 4  1930  15 Jul 1930 - 16:00   ...                ARG                FRA
# 5  1930  16 Jul 1930 - 14:45   ...                CHI                MEX
# 6  1930  17 Jul 1930 - 12:45   ...                YUG                BOL
#
# [7 rows x 20 columns]

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
# Print the last 3 rows of df
df.tail(3)
# Out:
#      Year              Datetime  ... Home Team Initials Away Team Initials
# 849  2014  09 Jul 2014 - 17:00   ...                NED                ARG
# 850  2014  12 Jul 2014 - 17:00   ...                BRA                NED
# 851  2014  13 Jul 2014 - 16:00   ...                GER                ARG
#
# [3 rows x 20 columns]

# %% [markdown]
# Get a concise summary of the data using `.info()`.

# %%
# Print a concise summary of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
# Print the number of rows and columns in df
df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
# Print the column names of df
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting DataFrame information

# %% [markdown]
# When looking at the DataFrame's `.head()`, you might have noticed that the games are structured chronologically in the DataFrame.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
# Print rows 3 through 5
df[3:6]
# Out:
#    Year              Datetime  ... Home Team Initials Away Team Initials
# 3  1930  14 Jul 1930 - 14:50   ...                ROU                PER
# 4  1930  15 Jul 1930 - 16:00   ...                ARG                FRA
# 5  1930  16 Jul 1930 - 14:45   ...                CHI                MEX
#
# [3 rows x 20 columns]

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested in printing out the, "Home Team Name" and the, "Away Team Name."

# %%
# Print rows 5 through 9 and columns 'Home Team Name' and 'Away Team Name'
df[5:10][['Home Team Name', 'Away Team Name']]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
# method 2 for slicing
df[['Home Team Name', 'Away Team Name']][5:10]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %%
# method 3 for slicing and this is the fastest way
df.loc[5:10,['Home Team Name', 'Away Team Name']]
# Out:
#    Home Team Name Away Team Name
# 5           Chile         Mexico
# 6      Yugoslavia        Bolivia
# 7             USA       Paraguay
# 8         Uruguay           Peru
# 9           Chile         France
# 10      Argentina         Mexico

# %%
# Print all info for games played in 1950 for Group 3
# 1st way df[df['Year'] == 1950] just to find games palyed in 1950
df.loc[(df['Year'] == 1950) & (df['Stage'] == 'Group 3')]
# Out:
#     Year              Datetime  ... Home Team Initials Away Team Initials
# 56  1950  25 Jun 1950 - 15:00   ...                SWE                ITA
# 61  1950  29 Jun 1950 - 15:30   ...                SWE                PAR
# 65  1950  02 Jul 1950 - 15:00   ...                ITA                PAR
#
# [3 rows x 20 columns]

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance column for the Group 3 games.

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
# Print the 'Attendance' column for games played in 1950 for Group 3
df.loc[(df['Year'] == 1950) & (df['Stage'] == 'Group 3'),['Attendance']]
# Out:
#     Attendance
# 56     36502.0
# 61      7903.0
# 65     25811.0

# %% [markdown]
# Throughout the entire history of the World Cup, how many home games were played by the Netherlands?

# %%
# Number of home games played by the Netherlands
df[df['Home Team Name'] == 'Netherlands'].shape[0]
# Out:
# 32

# %% [markdown]
# How many games were played by the Netherlands in total?

# %%
# Number of games played by the Netherlands in total
df.loc[(df['Home Team Name'] == 'Netherlands')| (df['Away Team Name'] == 'Netherlands')].shape[0]
# Out:
# 54

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 World Cup.
#
# #### Number of games the USA played in the 2014 world cup

# %%
df.loc[df['Year'] == 2014]
# Out:
#      Year              Datetime  ... Home Team Initials Away Team Initials
# 772  2014  12 Jun 2014 - 17:00   ...                BRA                CRO
# 773  2014  13 Jun 2014 - 13:00   ...                MEX                CMR
# 774  2014  13 Jun 2014 - 16:00   ...                ESP                NED
# 775  2014  13 Jun 2014 - 18:00   ...                CHI                AUS
# 776  2014  14 Jun 2014 - 13:00   ...                COL                GRE
# ..    ...                   ...  ...                ...                ...
# 847  2014  05 Jul 2014 - 17:00   ...                NED                CRC
# 848  2014  08 Jul 2014 - 17:00   ...                BRA                GER
# 849  2014  09 Jul 2014 - 17:00   ...                NED                ARG
# 850  2014  12 Jul 2014 - 17:00   ...                BRA                NED
# 851  2014  13 Jul 2014 - 16:00   ...                GER                ARG
#
# [80 rows x 20 columns]

# %%
df['Home Team Name'].unique()
# Out:
# array(['France', 'USA', 'Yugoslavia', 'Romania', 'Argentina', 'Chile',
#        'Uruguay', 'Brazil', 'Paraguay', 'Austria', 'Hungary',
#        'Switzerland', 'Sweden', 'Germany', 'Spain', 'Italy',
#        'Czechoslovakia', 'Cuba', 'England', 'Germany FR', 'Turkey',
#        'Soviet Union', 'Northern Ireland', 'Mexico', 'Wales', 'Portugal',
#        'Korea DPR', 'Peru', 'Belgium', 'Bulgaria', 'German DR', 'Zaire',
#        'Poland', 'Australia', 'Scotland', 'Netherlands', 'Haiti',
#        'Tunisia', 'Algeria', 'Honduras', 'Canada', 'Morocco',
#        'Korea Republic', 'Iraq', 'Denmark', 'rn">United Arab Emirates',
#        'Costa Rica', 'Cameroon', 'rn">Republic of Ireland', 'Colombia',
#        'Norway', 'Nigeria', 'Saudi Arabia', 'Bolivia', 'Russia', 'Greece',
#        'Jamaica', 'South Africa', 'Japan', 'Croatia', 'China PR',
#        'Senegal', 'Slovenia', 'Ecuador', 'rn">Trinidad and Tobago',
#        'rn">Serbia and Montenegro', 'Angola', 'Czech Republic', 'Togo',
#        'Iran', "C�te d'Ivoire", 'Ghana', 'Ukraine', 'Serbia',
#        'New Zealand', 'Slovakia', 'IR Iran', 'rn">Bosnia and Herzegovina'],
#       dtype=object)

# %%
df.loc[(df['Year'] == 2014) & ((df['Home Team Name'] == 'USA')| (df['Away Team Name'] == 'USA'))]
# Out:
#      Year              Datetime  ... Home Team Initials Away Team Initials
# 785  2014  16 Jun 2014 - 19:00   ...                GHA                USA
# 803  2014  22 Jun 2014 - 18:00   ...                USA                POR
# 816  2014  26 Jun 2014 - 13:00   ...                USA                GER
# 835  2014  01 Jul 2014 - 17:00   ...                BEL                USA
# 843  2014  01 Jul 2014 - 17:00   ...                BEL                USA
#
# [5 rows x 20 columns]

# %%
# Number of games the USA played in the 2014 world cup
df.loc[(df['Year'] == 2014) & ((df['Home Team Name'] == 'USA')| (df['Away Team Name'] == 'USA'))].shape[0]
# Out:
# 5

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 World Cup.

# %% [markdown]
# Hint 1: as a first step, create a new dataset that only contains games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
df1986 = df.loc[df['Year'] == 1986]
df1986
# Out:
#      Year              Datetime  ... Home Team Initials Away Team Initials
# 360  1986  31 May 1986 - 12:00   ...                BUL                ITA
# 361  1986  01 Jun 1986 - 16:00   ...                CAN                FRA
# 362  1986  01 Jun 1986 - 12:00   ...                ESP                BRA
# 363  1986  02 Jun 1986 - 12:00   ...                URS                HUN
# 364  1986  02 Jun 1986 - 12:00   ...                ARG                KOR
# 365  1986  02 Jun 1986 - 16:00   ...                MAR                POL
# 366  1986  03 Jun 1986 - 12:00   ...                ALG                NIR
# 367  1986  03 Jun 1986 - 12:00   ...                BEL                MEX
# 368  1986  03 Jun 1986 - 16:00   ...                POR                ENG
# 369  1986  04 Jun 1986 - 12:00   ...                PAR                IRQ
# 370  1986  04 Jun 1986 - 16:00   ...                SCO                DEN
# 371  1986  04 Jun 1986 - 12:00   ...                URU                FRG
# 372  1986  05 Jun 1986 - 12:00   ...                ITA                ARG
# 373  1986  05 Jun 1986 - 12:00   ...                FRA                URS
# 374  1986  05 Jun 1986 - 16:00   ...                KOR                BUL
# 375  1986  06 Jun 1986 - 12:00   ...                HUN                CAN
# 376  1986  06 Jun 1986 - 12:00   ...                BRA                ALG
# 377  1986  06 Jun 1986 - 16:00   ...                ENG                MAR
# 378  1986  07 Jun 1986 - 12:00   ...                NIR                ESP
# 379  1986  07 Jun 1986 - 12:00   ...                MEX                PAR
# 380  1986  07 Jun 1986 - 16:00   ...                POL                POR
# 381  1986  08 Jun 1986 - 12:00   ...                IRQ                BEL
# 382  1986  08 Jun 1986 - 16:00   ...                DEN                URU
# 383  1986  08 Jun 1986 - 12:00   ...                FRG                SCO
# 384  1986  09 Jun 1986 - 12:00   ...                HUN                FRA
# 385  1986  09 Jun 1986 - 12:00   ...                URS                CAN
# 386  1986  10 Jun 1986 - 12:00   ...                KOR                ITA
# 387  1986  10 Jun 1986 - 12:00   ...                ARG                BUL
# 388  1986  11 Jun 1986 - 12:00   ...                PAR                BEL
# 389  1986  11 Jun 1986 - 12:00   ...                IRQ                MEX
# 390  1986  11 Jun 1986 - 16:00   ...                POR                MAR
# 391  1986  11 Jun 1986 - 16:00   ...                ENG                POL
# 392  1986  12 Jun 1986 - 12:00   ...                NIR                BRA
# 393  1986  12 Jun 1986 - 12:00   ...                ALG                ESP
# 394  1986  13 Jun 1986 - 12:00   ...                SCO                URU
# 395  1986  13 Jun 1986 - 12:00   ...                DEN                FRG
# 396  1986  15 Jun 1986 - 16:00   ...                URS                BEL
# 397  1986  15 Jun 1986 - 12:00   ...                MEX                BUL
# 398  1986  16 Jun 1986 - 16:00   ...                ARG                URU
# 399  1986  16 Jun 1986 - 12:00   ...                BRA                POL
# 400  1986  17 Jun 1986 - 12:00   ...                ITA                FRA
# 401  1986  17 Jun 1986 - 16:00   ...                MAR                FRG
# 402  1986  18 Jun 1986 - 12:00   ...                ENG                PAR
# 403  1986  18 Jun 1986 - 16:00   ...                DEN                ESP
# 404  1986  21 Jun 1986 - 12:00   ...                BRA                FRA
# 405  1986  21 Jun 1986 - 16:00   ...                FRG                MEX
# 406  1986  22 Jun 1986 - 16:00   ...                ESP                BEL
# 407  1986  22 Jun 1986 - 12:00   ...                ARG                ENG
# 408  1986  25 Jun 1986 - 12:00   ...                FRA                FRG
# 409  1986  25 Jun 1986 - 16:00   ...                ARG                BEL
# 410  1986  28 Jun 1986 - 12:00   ...                FRA                BEL
# 411  1986  29 Jun 1986 - 12:00   ...                ARG                FRG
#
# [52 rows x 20 columns]

# %%
countries = set () # creating a set
home_countries = list(df1986['Home Team Name'].unique())
away_countries = list(df1986['Away Team Name'].unique())

home_countries, away_countries
# Out:
# (['Bulgaria',
#   'Canada',
#   'Spain',
#   'Soviet Union',
#   'Argentina',
#   'Morocco',
#   'Algeria',
#   'Belgium',
#   'Portugal',
#   'Paraguay',
#   'Scotland',
#   'Uruguay',
#   'Italy',
#   'France',
#   'Korea Republic',
#   'Hungary',
#   'Brazil',
#   'England',
#   'Northern Ireland',
#   'Mexico',
#   'Poland',
#   'Iraq',
#   'Denmark',
#   'Germany FR'],
#  ['Italy',
#   'France',
#   'Brazil',
#   'Hungary',
#   'Korea Republic',
#   'Poland',
#   'Northern Ireland',
#   'Mexico',
#   'England',
#   'Iraq',
#   'Denmark',
#   'Germany FR',
#   'Argentina',
#   'Soviet Union',
#   'Bulgaria',
#   'Canada',
#   'Algeria',
#   'Morocco',
#   'Spain',
#   'Paraguay',
#   'Portugal',
#   'Belgium',
#   'Uruguay',
#   'Scotland'])

# %%
print(len(home_countries))
home_countries += away_countries
print(len(home_countries)) 
print(len(set(home_countries)))
# Out:
# 24
# 48
# 24

# %%
# Number of countries participated in the 1986 world cup

 # Method two
countries1 = set()

home_countries_set = set(df.loc[df['Year'] == 1986, 'Home Team Name'].unique())
away_countries_set = set(df.loc[df['Year'] == 1986, 'Away Team Name'].unique())

countries1.update(home_countries_set)
countries1.update(away_countries_set)

len (countries1)
# Out:
# 24

# %% [markdown]
# In World Cup history, how many matches had 5 goals or more in total?

# %%
# Number of matches that had 5 or more goals in total
df['Total_Goals'] = df['Home Team Goals'] + df['Away Team Goals']
print(len(df[df['Total_Goals'] >= 5]))
# Out:
# 147

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column, "Half-time Goals."

# %%
# Create a new column 'Half-time Goals' in df
df['Half-time Goals'] = df['Half-time Home Goals'] + df['Half-time Away Goals']
df.head()
# Out:
#    Year              Datetime  ... Total_Goals Half-time Goals
# 0  1930  13 Jul 1930 - 15:00   ...           5               3
# 1  1930  13 Jul 1930 - 15:00   ...           3               2
# 2  1930  14 Jul 1930 - 12:45   ...           3               2
# 3  1930  14 Jul 1930 - 14:50   ...           4               1
# 4  1930  15 Jul 1930 - 16:00   ...           1               0
#
# [5 rows x 22 columns]

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
# Print all records containing the string 'Korea'
df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']
# Out:
# 179         Korea DPR
# 187         Korea DPR
# 374    Korea Republic
# 386    Korea Republic
# 434    Korea Republic
# 444    Korea Republic
# 480    Korea Republic
# 524    Korea Republic
# 593    Korea Republic
# 609    Korea Republic
# 635    Korea Republic
# 642    Korea Republic
# 655    Korea Republic
# 710    Korea Republic
# 753         Korea DPR
# 802    Korea Republic
# 818    Korea Republic
# Name: Home Team Name, dtype: object

# %% [markdown]
# Imagine that, for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
# Update the 'Home Team Name' and 'Home Team Initials' columns 
df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name'] = 'Korea'

df.loc[df['Home Team Name'].str.contains('Korea'), 'Home Team Name']
# Out:
# 179    Korea
# 187    Korea
# 374    Korea
# 386    Korea
# 434    Korea
# 444    Korea
# 480    Korea
# 524    Korea
# 593    Korea
# 609    Korea
# 635    Korea
# 642    Korea
# 655    Korea
# 710    Korea
# 753    Korea
# 802    Korea
# 818    Korea
# Name: Home Team Name, dtype: object

# %%
df.loc[df['Home Team Name'] == 'Korea DPR', 'Home Team Name'] = 'Korea'
df.loc[df['Home Team Name'] == 'Korea Republic', 'Home Team Name'] = 'Korea'
df.loc[df['Away Team Name'] == 'Korea DPR', 'Away Team Name'] = 'Korea'
df.loc[df['Away Team Name'] == 'Korea Republic', 'Away Team Name'] = 'Korea'
df.loc[df['Home Team Initials'] == 'KOR', 'Home Team Initials'] = 'NSK'
df.loc[df['Home Team Initials'] == 'KOR', 'Home Team Initials'] = 'NSK'
df.loc[df['Away Team Initials'] == 'PRK', 'Away Team Initials'] = 'NSK'
df.loc[df['Away Team Initials'] == 'PRK', 'Away Team Initials'] = 'NSK'

# %% [markdown]
# Make sure to verify your answer!

# %%
# Check the updated columns
df.loc[df['Home Team Name'].str.contains('Korea')]
# Out:
#      Year              Datetime  ... Total_Goals Half-time Goals
# 179  1966  15 Jul 1966 - 19:30   ...           2               1
# 187  1966  19 Jul 1966 - 19:30   ...           1               1
# 374  1986  05 Jun 1986 - 16:00   ...           2               1
# 386  1986  10 Jun 1986 - 12:00   ...           5               1
# 434  1990  17 Jun 1990 - 21:00   ...           4               2
# 444  1990  21 Jun 1990 - 17:00   ...           1               0
# 480  1994  23 Jun 1994 - 19:30   ...           0               0
# 524  1998  13 Jun 1998 - 17:30   ...           4               1
# 593  2002  04 Jun 2002 - 20:30   ...           2               1
# 609  2002  10 Jun 2002 - 15:30   ...           2               1
# 635  2002  18 Jun 2002 - 20:30   ...           3               0
# 642  2002  29 Jun 2002 - 20:00   ...           5               4
# 655  2006  13 Jun 2006 - 15:00   ...           3               1
# 710  2010  12 Jun 2010 - 13:30   ...           2               1
# 753  2010  25 Jun 2010 - 16:00   ...           3               2
# 802  2014  22 Jun 2014 - 16:00   ...           6               3
# 818  2014  26 Jun 2014 - 17:00   ...           1               0
#
# [17 rows x 22 columns]

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to access data within Pandas!
